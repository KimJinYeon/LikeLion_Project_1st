# %%
import pandas as pd
from datetime import date, timedelta

# %%
corona = pd.read_csv('./data/coronaboard(2021-09-26).csv')
vaccine = pd.read_csv('./data/bloomberg(2021-09-26).csv')
country = pd.read_csv('./data/country.csv')

# %%
jandam = corona.loc[corona['국가'] == '잔담🚢', :]
jandam
# Out:
#       국가  확진자  치료중  위중증  사망자   완치 치명(%)  완치(%) 발생률 인구수
# 215  잔담🚢    9  0.0  NaN    2  7.0  22.2   77.8   -   -

# %%
corona.drop(jandam.index, inplace=True)

# %%
corona['국가']
# Out:
# 0          미국🇺🇸
# 1          인도🇮🇳
# 2         브라질🇧🇷
# 3          영국🇬🇧
# 4         러시아🇷🇺
#          ...
# 217     마셜 제도🇲🇭
# 218      바누아투🇻🇺
# 219       사모아🇼🇸
# 220    세인트헬레나🇸🇭
# 221    미크로네시아🇫🇲
# Name: 국가, Length: 221, dtype: object

# %%
corona['국가코드'] = corona['국가'].str[-2:]

# %%
corona['국가'] = corona['국가'].str[:-2]

# %%
corona.head()
# Out:
#     국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  완치(%)  \
# 0   미국   🇺🇸  43728094  9857997.0  22378.0  706073  33164024.0   1.6   75.8
# 1   인도   🇮🇳  33673010   308341.0   8944.0  447169  32917500.0   1.3   97.8
# 2  브라질   🇧🇷  21343304   415150.0   8318.0  594246  20333908.0   2.8   95.3
# 3   영국   🇬🇧   7631233  1335993.0    916.0  136105   6159135.0   1.8   80.7
# 4  러시아   🇷🇺   7420913   612409.0   2300.0  203900   6604604.0   2.7   89.0
#
#       발생률         인구수
# 0  132177   331002651
# 1   24405  1380004385
# 2  100452   212559417
# 3  112899    67886011
# 4   51003   145934462

# %%
corona.columns
# Out:
# Index(['국가', '국가코드', '확진자', '치료중', '위중증', '사망자', '완치', '치명(%)', '완치(%)', '발생률',
#        '인구수'],
#       dtype='object')

# %%
col = ['국가', '국가코드', '확진자', '치료중', '위중증', '사망자', '완치', '치명(%)', '완치(%)', '발생률', '인구수']

# %%
corona = corona[col].copy()

# %%
corona.head()
# Out:
#     국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  완치(%)  \
# 0   미국   🇺🇸  43728094  9857997.0  22378.0  706073  33164024.0   1.6   75.8
# 1   인도   🇮🇳  33673010   308341.0   8944.0  447169  32917500.0   1.3   97.8
# 2  브라질   🇧🇷  21343304   415150.0   8318.0  594246  20333908.0   2.8   95.3
# 3   영국   🇬🇧   7631233  1335993.0    916.0  136105   6159135.0   1.8   80.7
# 4  러시아   🇷🇺   7420913   612409.0   2300.0  203900   6604604.0   2.7   89.0
#
#       발생률         인구수
# 0  132177   331002651
# 1   24405  1380004385
# 2  100452   212559417
# 3  112899    67886011
# 4   51003   145934462

# %%
corona.tail()
# Out:
#          국가 국가코드  확진자  치료중  위중증  사망자   완치 치명(%)  완치(%)  발생률     인구수
# 217   마셜 제도   🇲🇭    4  0.0  NaN    0  4.0     -  100.0   68   59190
# 218    바누아투   🇻🇺    4  0.0  NaN    1  3.0    25   75.0   13  307145
# 219     사모아   🇼🇸    3  0.0  NaN    0  3.0     -  100.0   15  198414
# 220  세인트헬레나   🇸🇭    2  0.0  NaN    0  2.0     -  100.0  329    6077
# 221  미크로네시아   🇫🇲    1  0.0  NaN    0  1.0     -  100.0    9  115023

# %%
country
# Out:
#     국문(코로나보드)      영문(블룸버그)   나라        비고_뜻
# 0          가나         Ghana  NaN         NaN
# 1          가봉         Gabon  NaN         NaN
# 2        가이아나        Guyana  NaN         NaN
# 3         감비아        Gambia  NaN         NaN
# 4        과들루프           NaN  프랑스  Guadeloupe
# ..        ...           ...  ...         ...
# 222       NaN         Nauru  NaN         나우루
# 223       NaN         Tonga  NaN          통가
# 224       NaN  Turkmenistan  NaN     투르크메니스탄
# 225       NaN        Jersey  NaN          저지
# 226       NaN            EU  NaN         NaN
#
# [227 rows x 4 columns]

# %%
vaccine
# Out:
#     Countries and regions Doses administered Enough for % of people  \
# 0            Global Total         6123019468                      –
# 1          Mainland China         2194467000                   78.4
# 2                   India          855844677                   31.3
# 3                      EU          562043453                   63.3
# 4                    U.S.          389372689                   60.8
# ..                    ...                ...                    ...
# 221                 Nauru              14863                   57.2
# 222            St. Helena               7892                   65.8
# 223      Falkland Islands               4407                   73.5
# 224            Montserrat               2856                   28.6
# 225               Eritrea                  –                      –
#
#     given 1+ dose fully vaccinated Daily rate of doses administered
# 0               –                –                         29115645
# 1            78.6             73.0                          3492857
# 2            45.9             16.1                          7388179
# 3            67.1             64.4                          1028193
# 4            64.2             55.2                           693164
# ..            ...              ...                              ...
# 221          58.6             55.8                                4
# 222          72.7             58.9                                8
# 223          87.7             59.2                              202
# 224          29.4             27.7                                2
# 225             –                –                                –
#
# [226 rows x 6 columns]

# %%
corona = corona.merge(country, left_on='국가', right_on='국문(코로나보드)')

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  43728094  9857997.0  22378.0  706073  33164024.0   1.6
# 1        인도   🇮🇳  33673010   308341.0   8944.0  447169  32917500.0   1.3
# 2       브라질   🇧🇷  21343304   415150.0   8318.0  594246  20333908.0   2.8
# 3        영국   🇬🇧   7631233  1335993.0    916.0  136105   6159135.0   1.8
# 4       러시아   🇷🇺   7420913   612409.0   2300.0  203900   6604604.0   2.7
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 214   마셜 제도   🇲🇭         4        0.0      NaN       0         4.0     -
# 215    바누아투   🇻🇺         4        0.0      NaN       1         3.0    25
# 216     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 217  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 218  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수 국문(코로나보드)    영문(블룸버그)   나라  \
# 0     75.8  132177   331002651        미국        U.S.  NaN
# 1     97.8   24405  1380004385        인도       India  NaN
# 2     95.3  100452   212559417       브라질      Brazil  NaN
# 3     80.7  112899    67886011        영국        U.K.  NaN
# 4     89.0   51003   145934462       러시아      Russia  NaN
# ..     ...     ...         ...       ...         ...  ...
# 214  100.0      68       59190     마셜 제도         NaN  NaN
# 215   75.0      13      307145      바누아투         NaN  NaN
# 216  100.0      15      198414       사모아       Samoa  NaN
# 217  100.0     329        6077    세인트헬레나  St. Helena  NaN
# 218  100.0       9      115023    미크로네시아  Micronesia  NaN
#
#                                  비고_뜻
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 214  Republic of the Marshall Islands
# 215               Republic of Vanuatu
# 216                               NaN
# 217                               NaN
# 218                               NaN
#
# [219 rows x 15 columns]

# %%
corona.drop(['국문(코로나보드)', '나라', '비고_뜻'], axis=1, inplace=True)

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  43728094  9857997.0  22378.0  706073  33164024.0   1.6
# 1        인도   🇮🇳  33673010   308341.0   8944.0  447169  32917500.0   1.3
# 2       브라질   🇧🇷  21343304   415150.0   8318.0  594246  20333908.0   2.8
# 3        영국   🇬🇧   7631233  1335993.0    916.0  136105   6159135.0   1.8
# 4       러시아   🇷🇺   7420913   612409.0   2300.0  203900   6604604.0   2.7
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 214   마셜 제도   🇲🇭         4        0.0      NaN       0         4.0     -
# 215    바누아투   🇻🇺         4        0.0      NaN       1         3.0    25
# 216     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 217  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 218  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수    영문(블룸버그)
# 0     75.8  132177   331002651        U.S.
# 1     97.8   24405  1380004385       India
# 2     95.3  100452   212559417      Brazil
# 3     80.7  112899    67886011        U.K.
# 4     89.0   51003   145934462      Russia
# ..     ...     ...         ...         ...
# 214  100.0      68       59190         NaN
# 215   75.0      13      307145         NaN
# 216  100.0      15      198414       Samoa
# 217  100.0     329        6077  St. Helena
# 218  100.0       9      115023  Micronesia
#
# [219 rows x 12 columns]

# %%
corona = corona.merge(vaccine, left_on='영문(블룸버그)', right_on='Countries and regions')

# %%
corona.drop(['영문(블룸버그)'], axis=1, inplace=True)

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  43728094  9857997.0  22378.0  706073  33164024.0   1.6
# 1        인도   🇮🇳  33673010   308341.0   8944.0  447169  32917500.0   1.3
# 2       브라질   🇧🇷  21343304   415150.0   8318.0  594246  20333908.0   2.8
# 3        영국   🇬🇧   7631233  1335993.0    916.0  136105   6159135.0   1.8
# 4       러시아   🇷🇺   7420913   612409.0   2300.0  203900   6604604.0   2.7
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 189    몬트세랫   🇲🇸        33        2.0      NaN       1        30.0   3.0
# 190  솔로몬 제도   🇸🇧        20        0.0      NaN       0        20.0     -
# 191     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 192  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 193  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수 Countries and regions Doses administered  \
# 0     75.8  132177   331002651                  U.S.          389372689
# 1     97.8   24405  1380004385                 India          855844677
# 2     95.3  100452   212559417                Brazil          230477848
# 3     80.7  112899    67886011                  U.K.           93421423
# 4     89.0   51003   145934462                Russia           89301130
# ..     ...     ...         ...                   ...                ...
# 189   90.9    6611        4992            Montserrat               2856
# 190  100.0      29      686884       Solomon Islands              97744
# 191  100.0      15      198414                 Samoa             149431
# 192  100.0     329        6077            St. Helena               7892
# 193  100.0       9      115023            Micronesia              71686
#
#     Enough for % of people given 1+ dose fully vaccinated  \
# 0                     60.8          64.2             55.2
# 1                     31.3          45.9             16.1
# 2                     55.8          70.7             40.6
# 3                     69.9          72.9             66.9
# 4                     30.4          32.3             28.3
# ..                     ...           ...              ...
# 189                   28.6          29.4             27.7
# 190                    7.6          11.6              3.6
# 191                   37.2          49.3             25.0
# 192                   65.8          72.7             58.9
# 193                   34.5          41.6                –
#
#     Daily rate of doses administered
# 0                             693164
# 1                            7388179
# 2                            1411550
# 3                              73687
# 4                             223501
# ..                               ...
# 189                                2
# 190                             2902
# 191                              981
# 192                                8
# 193                              294
#
# [194 rows x 17 columns]

# %%
# 어제 날짜
yesterday = date.today() - timedelta(1)
yesterday = yesterday.strftime('%Y-%m-%d')

# 파일명 정하기
file_name = f'./data/data_merged({yesterday}).csv'

# %%
corona.to_csv(file_name, index=False, encoding='utf-8-sig')
